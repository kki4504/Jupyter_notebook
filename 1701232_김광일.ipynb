# %% [markdown]
# # 중간고사 답지
# - 학번 : 1701232
# - 이름 : 김광일

# %% [markdown]
# # 2

# %%
import pandas as pd

# %%
df = pd.read_csv('OOP_results.csv', index_col = 'StdNum')

# %%
df
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1809349         OOP         20        19       25         11     75
# 1968144         OOP         20        17       25         29     91
# 1993289         OOP         20        18       16         28     82
# 1891044         OOP         20        16       21         12     69
# 1879982         OOP         20        17       26         29     92
# 1726380         OOP         20         9       20         26     75
# 1724481         OOP          0         0        0          0      0
# 1804630         OOP         20        12       10          5     47
# 1989046         OOP          0         0        0          0      0
# 1974935         OOP         20        15       15         11     61
# 1857008         OOP         19         9       12          8     48
# 1993809         OOP         16         2       17          4     39
# 1897281         OOP         20        17       30         30     97
# ...

# %% [markdown]
# # 3

# %%
df.head(10)
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1809349         OOP         20        19       25         11     75
# 1968144         OOP         20        17       25         29     91
# 1993289         OOP         20        18       16         28     82
# 1891044         OOP         20        16       21         12     69
# 1879982         OOP         20        17       26         29     92
# 1726380         OOP         20         9       20         26     75
# 1724481         OOP          0         0        0          0      0
# 1804630         OOP         20        12       10          5     47
# 1989046         OOP          0         0        0          0      0
# 1974935         OOP         20        15       15         11     61

# %% [markdown]
# # 4

# %%
df.dtypes
# Out:
# SubjectName    object
# AttdPoint       int64
# Homework        int64
# Midterm         int64
# Finalterm       int64
# Total           int64
# dtype: object

# %% [markdown]
# # 5

# %%
df.shape
# Out:
# (44, 6)

# %% [markdown]
# # 6

# %%
df['Finalterm'].max()
# Out:
# 30

# %% [markdown]
# # 7

# %%
df['Midterm']
# Out:
# StdNum
# 1809349    25
# 1968144    25
# 1993289    16
# 1891044    21
# 1879982    26
# 1726380    20
# 1724481     0
# 1804630    10
# 1989046     0
# 1974935    15
# 1857008    12
# 1993809    17
# 1897281    30
# 1875290    12
# 1954022    19
# 1934243    26
# 1811646    22
# 1721470     0
# 1769727     9
# 1950136     1
# 1974440    29
# 1816207     0
# 1820158    19
# 1806474     7
# 1836508    17
# 1717040     0
# 1818588     5
# 1943825    27
# 1914788     0
# 1864612    13
# 1831484    11
# 1741933     6
# 1710335     2
# 1911496     8
# 1788542    19
# 1873632     8
# 1920569    10
# 1760212     7
# 1835080    12
# 1786659    13
# 1775658     2
# 1886038    18
# 1852486     3
# 1908921     0
# Name: Midterm, dtype: int64

# %%
# 8

# %%
df[['Midterm', 'Finalterm']]
# Out:
#          Midterm  Finalterm
# StdNum
# 1809349       25         11
# 1968144       25         29
# 1993289       16         28
# 1891044       21         12
# 1879982       26         29
# 1726380       20         26
# 1724481        0          0
# 1804630       10          5
# 1989046        0          0
# 1974935       15         11
# 1857008       12          8
# 1993809       17          4
# 1897281       30         30
# 1875290       12          8
# 1954022       19         14
# 1934243       26         30
# 1811646       22         22
# 1721470        0          0
# 1769727        9          3
# 1950136        1          0
# 1974440       29         28
# 1816207        0          0
# 1820158       19         29
# 1806474        7          4
# 1836508       17         13
# 1717040        0          0
# 1818588        5          3
# 1943825       27         10
# 1914788        0          0
# 1864612       13          2
# 1831484       11          5
# 1741933        6          1
# ...

# %%
# 9

# %%
Midterm = df['Midterm']>=25

# %%
df[Midterm]
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1809349         OOP         20        19       25         11     75
# 1968144         OOP         20        17       25         29     91
# 1879982         OOP         20        17       26         29     92
# 1897281         OOP         20        17       30         30     97
# 1934243         OOP         20        17       26         30     93
# 1974440         OOP         20        17       29         28     94
# 1943825         OOP         20        20       27         10     77

# %%
# 10

# %%
Finalterm = df['Finalterm'] >= 25

# %%
df[Finalterm][['Finalterm','Total']]
# Out:
#          Finalterm  Total
# StdNum
# 1968144         29     91
# 1993289         28     82
# 1879982         29     92
# 1726380         26     75
# 1897281         30     97
# 1934243         30     93
# 1974440         28     94
# 1820158         29     81

# %%
# 11

# %%
# 12

# %%
df.loc[[1934243, 1968144]]
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1934243         OOP         20        17       26         30     93
# 1968144         OOP         20        17       25         29     91

# %%
# 13

# %%
df[df['Total'] == 0]
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1724481         OOP          0         0        0          0      0
# 1989046         OOP          0         0        0          0      0
# 1721470         OOP          0         0        0          0      0
# 1816207         OOP          0         0        0          0      0
# 1717040         OOP          0         0        0          0      0
# 1914788         OOP          0         0        0          0      0
# 1908921         OOP          0         0        0          0      0

# %%
#14

# %%
import numpy as np

# %%
df[df['Total'] == 0] = np.NaN

# %%
# 15

# %%
df
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1809349         OOP       20.0      19.0     25.0       11.0   75.0
# 1968144         OOP       20.0      17.0     25.0       29.0   91.0
# 1993289         OOP       20.0      18.0     16.0       28.0   82.0
# 1891044         OOP       20.0      16.0     21.0       12.0   69.0
# 1879982         OOP       20.0      17.0     26.0       29.0   92.0
# 1726380         OOP       20.0       9.0     20.0       26.0   75.0
# 1724481         NaN        NaN       NaN      NaN        NaN    NaN
# 1804630         OOP       20.0      12.0     10.0        5.0   47.0
# 1989046         NaN        NaN       NaN      NaN        NaN    NaN
# 1974935         OOP       20.0      15.0     15.0       11.0   61.0
# 1857008         OOP       19.0       9.0     12.0        8.0   48.0
# 1993809         OOP       16.0       2.0     17.0        4.0   39.0
# 1897281         OOP       20.0      17.0     30.0       30.0   97.0
# ...

# %%
df[df['Total'].isnull()]
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1724481         NaN        NaN       NaN      NaN        NaN    NaN
# 1989046         NaN        NaN       NaN      NaN        NaN    NaN
# 1721470         NaN        NaN       NaN      NaN        NaN    NaN
# 1816207         NaN        NaN       NaN      NaN        NaN    NaN
# 1717040         NaN        NaN       NaN      NaN        NaN    NaN
# 1914788         NaN        NaN       NaN      NaN        NaN    NaN
# 1908921         NaN        NaN       NaN      NaN        NaN    NaN

# %%
# 16

# %%
df = df.sort_values(by='StdNum', ascending=True)

# %%
df
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1710335         OOP       20.0      13.0      2.0        4.0   39.0
# 1717040         NaN        NaN       NaN      NaN        NaN    NaN
# 1721470         NaN        NaN       NaN      NaN        NaN    NaN
# 1724481         NaN        NaN       NaN      NaN        NaN    NaN
# 1726380         OOP       20.0       9.0     20.0       26.0   75.0
# 1741933         OOP       20.0      10.0      6.0        1.0   37.0
# 1760212         OOP       20.0      15.0      7.0        3.0   45.0
# 1769727         OOP       20.0      14.0      9.0        3.0   46.0
# 1775658         OOP       20.0      12.0      2.0        2.0   36.0
# 1786659         OOP       20.0      17.0     13.0        4.0   54.0
# 1788542         OOP       20.0      18.0     19.0        6.0   63.0
# 1804630         OOP       20.0      12.0     10.0        5.0   47.0
# 1806474         OOP       20.0       9.0      7.0        4.0   40.0
# ...

# %%
# 17

# %%
Homework = (df.Homework == 2) | (df.Homework == 9) | (df['Homework'].isna())

# %%
df[Homework]
# Out:
#         SubjectName  AttdPoint  Homework  Midterm  Finalterm  Total
# StdNum
# 1717040         NaN        NaN       NaN      NaN        NaN    NaN
# 1721470         NaN        NaN       NaN      NaN        NaN    NaN
# 1724481         NaN        NaN       NaN      NaN        NaN    NaN
# 1726380         OOP       20.0       9.0     20.0       26.0   75.0
# 1806474         OOP       20.0       9.0      7.0        4.0   40.0
# 1816207         NaN        NaN       NaN      NaN        NaN    NaN
# 1857008         OOP       19.0       9.0     12.0        8.0   48.0
# 1908921         NaN        NaN       NaN      NaN        NaN    NaN
# 1914788         NaN        NaN       NaN      NaN        NaN    NaN
# 1950136         OOP       17.0       2.0      1.0        0.0   20.0
# 1989046         NaN        NaN       NaN      NaN        NaN    NaN
# 1993809         OOP       16.0       2.0     17.0        4.0   39.0

# %%
# 18

# %%
# 19

# %%
df.rename(columns = {'StdNum' : '학번', 'SubjectName' : '과목명', 'AttdPoint' : '출결점수', 'Homework' : '과제', 'Midterm' : '중간고사', 'Finalterm' : '기말고사', 'Total' : '총점'}, inplace= True)

# %%
df
# Out:
#          과목명  출결점수    과제  중간고사  기말고사    총점
# StdNum
# 1710335  OOP  20.0  13.0   2.0   4.0  39.0
# 1717040  NaN   NaN   NaN   NaN   NaN   NaN
# 1721470  NaN   NaN   NaN   NaN   NaN   NaN
# 1724481  NaN   NaN   NaN   NaN   NaN   NaN
# 1726380  OOP  20.0   9.0  20.0  26.0  75.0
# 1741933  OOP  20.0  10.0   6.0   1.0  37.0
# 1760212  OOP  20.0  15.0   7.0   3.0  45.0
# 1769727  OOP  20.0  14.0   9.0   3.0  46.0
# 1775658  OOP  20.0  12.0   2.0   2.0  36.0
# 1786659  OOP  20.0  17.0  13.0   4.0  54.0
# 1788542  OOP  20.0  18.0  19.0   6.0  63.0
# 1804630  OOP  20.0  12.0  10.0   5.0  47.0
# 1806474  OOP  20.0   9.0   7.0   4.0  40.0
# 1809349  OOP  20.0  19.0  25.0  11.0  75.0
# 1811646  OOP  20.0  14.0  22.0  22.0  78.0
# 1816207  NaN   NaN   NaN   NaN   NaN   NaN
# 1818588  OOP  20.0  16.0   5.0   3.0  44.0
# 1820158  OOP  20.0  13.0  19.0  29.0  81.0
# 1831484  OOP  20.0  10.0  11.0   5.0  46.0
# 1835080  OOP  20.0  12.0  12.0   4.0  48.0
# 1836508  OOP  20.0  11.0  17.0  13.0  61.0
# ...

# %%
# 20

# %%
def get_grade(num) :
    if conditionA and conditionB :
       code1;
    elif conditionC:
        code2;
    .... // 생략
    else :
        codeN;
